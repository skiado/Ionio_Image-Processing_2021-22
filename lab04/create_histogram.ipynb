# %%
from PIL import Image

im = Image.open('parrot.png')
print(im.size)
histo = []
for i in range(256):
    histo.append(0)
for x in range(im.size[0]):
    for y in range(im.size[1]):
        f = im.getpixel((x,y))
        histo[f] += 1
print(histo)
# Out:
# (150, 200)
# ...
